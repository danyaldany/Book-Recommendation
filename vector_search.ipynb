# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma

# %%
from dotenv import load_dotenv

load_dotenv()   #python-dotenv package to load environment variables 
                #from a .env file into your Python environment.
# Out:
# True

# %%
import pandas as pd

#we simply load the dataset previously we cleaned it from raw data
books = pd.read_csv('books_cleaned.csv')
books.head(3)
# Out:
#           isbn13      isbn10           title                          authors  \
# 0  9780002005883  0002005883          Gilead               Marilynne Robinson
# 1  9780002261982  0002261987    Spider's Web  Charles Osborne;Agatha Christie
# 2  9780006178736  0006178731  Rage of angels                   Sidney Sheldon
#
#                       categories  \
# 0                        Fiction
# 1  Detective and mystery stories
# 2                        Fiction
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=FKo2T...
#
#                                          description  published_year  \
# 0  A NOVEL THAT READERS and critics have been eag...          2004.0
# 1  A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2  A memorable, mesmerizing heroine Jennifer -- b...          1993.0
#
#    average_rating  num_pages  ratings_count         title_subtitle  \
# 0            3.85      247.0          361.0                 Gilead
# 1            3.83      241.0         5164.0  Spider's Web: A Novel
# 2            3.93      512.0        29532.0         Rage of angels
#
#                                   tagged_description
# 0  9780002005883: A NOVEL THAT READERS and critic...
# 1  9780002261982: A new 'Christie for Christmas' ...
# 2  9780006178736: A memorable, mesmerizing heroin...

# %%
books['tagged_description'].to_csv('tagged_description.txt',
                                  sep = '\n',
                                  index = False,
                                  header= False)

# %%
raw_documents = TextLoader("tagged_description.txt",encoding="utf-8").load()
                                    #encoding="utf-8" means:
                                    #“Read the file in a language that can handle almost every character — English, Urdu, emojis, etc.”

# Create a splitter — adjust chunk_size as needed
text_splitter = CharacterTextSplitter(
    chunk_size=400, # When cutting the book, each page should have 500 characters (letters, spaces, symbols).”
    chunk_overlap=0, #“Don’t repeat any text between pages.”
    separator="\n"
)

# Split documents
documents = text_splitter.split_documents(raw_documents)
# Out:
# Created a chunk of size 1169, which is longer than the specified 400
# Created a chunk of size 1215, which is longer than the specified 400
# Created a chunk of size 484, which is longer than the specified 400
# Created a chunk of size 483, which is longer than the specified 400
# Created a chunk of size 961, which is longer than the specified 400
# Created a chunk of size 844, which is longer than the specified 400
# Created a chunk of size 882, which is longer than the specified 400
# Created a chunk of size 1089, which is longer than the specified 400
# Created a chunk of size 1190, which is longer than the specified 400
# Created a chunk of size 514, which is longer than the specified 400
# Created a chunk of size 753, which is longer than the specified 400
# Created a chunk of size 729, which is longer than the specified 400
# Created a chunk of size 722, which is longer than the specified 400
# Created a chunk of size 474, which is longer than the specified 400
# Created a chunk of size 1268, which is longer than the specified 400
# Created a chunk of size 682, which is longer than the specified 400
# Created a chunk of size 554, which is longer than the specified 400
# Created a chunk of size 522, which is longer than the specified 400
# Created a chunk of size 788, which is longer than the specified 400
# Created a chunk of size 565, which is longer than the specified 400
# Created a chunk of size 524, which is longer than the specified 400
# Created a chunk of size 534, which is longer than the specified 400
# Created a chunk of size 560, which is longer than the specified 400
# Created a chunk of size 564, which is longer than the specified 400
# Created a chunk of size 411, which is longer than the specified 400
# Created a chunk of size 462, which is longer than the specified 400
# Created a chunk of size 596, which is longer than the specified 400
# Created a chunk of size 477, which is longer than the specified 400
# Created a chunk of size 460, which is longer than the specified 400
# Created a chunk of size 615, which is longer than the specified 400
# Created a chunk of size 420, which is longer than the specified 400
# Created a chunk of size 888, which is longer than the specified 400
# Created a chunk of size 694, which is longer than the specified 400
# Created a chunk of size 2011, which is longer than the specified 400
# Created a chunk of size 480, which is longer than the specified 400
# Created a chunk of size 521, which is longer than the specified 400
# Created a chunk of size 648, which is longer than the specified 400
# Created a chunk of size 779, which is longer than the specified 400
# Created a chunk of size 687, which is longer than the specified 400
# Created a chunk of size 549, which is longer than the specified 400
# Created a chunk of size 1226, which is longer than the specified 400
# Created a chunk of size 407, which is longer than the specified 400
# Created a chunk of size 1185, which is longer than the specified 400
# Created a chunk of size 1215, which is longer than the specified 400
# Created a chunk of size 1192, which is longer than the specified 400
# Created a chunk of size 1058, which is longer than the specified 400
# Created a chunk of size 689, which is longer than the specified 400
# Created a chunk of size 877, which is longer than the specified 400
# Created a chunk of size 767, which is longer than the specified 400
# Created a chunk of size 418, which is longer than the specified 400
# Created a chunk of size 724, which is longer than the specified 400
# Created a chunk of size 527, which is longer than the specified 400
# Created a chunk of size 522, which is longer than the specified 400
# Created a chunk of size 900, which is longer than the specified 400
# Created a chunk of size 1271, which is longer than the specified 400
# Created a chunk of size 559, which is longer than the specified 400
# Created a chunk of size 1636, which is longer than the specified 400
# Created a chunk of size 437, which is longer than the specified 400
# Created a chunk of size 778, which is longer than the specified 400
# Created a chunk of size 717, which is longer than the specified 400
# Created a chunk of size 515, which is longer than the specified 400
# Created a chunk of size 959, which is longer than the specified 400
# Created a chunk of size 1133, which is longer than the specified 400
# Created a chunk of size 1326, which is longer than the specified 400
# Created a chunk of size 852, which is longer than the specified 400
# Created a chunk of size 802, which is longer than the specified 400
# Created a chunk of size 1120, which is longer than the specified 400
# Created a chunk of size 837, which is longer than the specified 400
# Created a chunk of size 733, which is longer than the specified 400
# Created a chunk of size 1196, which is longer than the specified 400
# Created a chunk of size 711, which is longer than the specified 400
# Created a chunk of size 774, which is longer than the specified 400
# Created a chunk of size 767, which is longer than the specified 400
# Created a chunk of size 768, which is longer than the specified 400
# Created a chunk of size 717, which is longer than the specified 400
# Created a chunk of size 2013, which is longer than the specified 400
# Created a chunk of size 1287, which is longer than the specified 400
# Created a chunk of size 1232, which is longer than the specified 400
# Created a chunk of size 730, which is longer than the specified 400
# Created a chunk of size 751, which is longer than the specified 400
# Created a chunk of size 446, which is longer than the specified 400
# Created a chunk of size 1243, which is longer than the specified 400
# Created a chunk of size 913, which is longer than the specified 400
# Created a chunk of size 845, which is longer than the specified 400
# Created a chunk of size 1127, which is longer than the specified 400
# Created a chunk of size 1074, which is longer than the specified 400
# Created a chunk of size 1319, which is longer than the specified 400
# Created a chunk of size 2835, which is longer than the specified 400
# Created a chunk of size 571, which is longer than the specified 400
# Created a chunk of size 1142, which is longer than the specified 400
# Created a chunk of size 1005, which is longer than the specified 400
# Created a chunk of size 716, which is longer than the specified 400
# Created a chunk of size 711, which is longer than the specified 400
# Created a chunk of size 2511, which is longer than the specified 400
# Created a chunk of size 955, which is longer than the specified 400
# Created a chunk of size 640, which is longer than the specified 400
# Created a chunk of size 406, which is longer than the specified 400
# Created a chunk of size 524, which is longer than the specified 400
# Created a chunk of size 794, which is longer than the specified 400
# Created a chunk of size 1423, which is longer than the specified 400
# Created a chunk of size 1084, which is longer than the specified 400
# Created a chunk of size 1145, which is longer than the specified 400
# Created a chunk of size 1269, which is longer than the specified 400
# Created a chunk of size 791, which is longer than the specified 400
# Created a chunk of size 1087, which is longer than the specified 400
# Created a chunk of size 875, which is longer than the specified 400
# Created a chunk of size 877, which is longer than the specified 400
# Created a chunk of size 807, which is longer than the specified 400
# Created a chunk of size 1813, which is longer than the specified 400
# Created a chunk of size 1831, which is longer than the specified 400
# Created a chunk of size 1065, which is longer than the specified 400
# Created a chunk of size 956, which is longer than the specified 400
# Created a chunk of size 1181, which is longer than the specified 400
# Created a chunk of size 1285, which is longer than the specified 400
# Created a chunk of size 1643, which is longer than the specified 400
# Created a chunk of size 758, which is longer than the specified 400
# Created a chunk of size 1931, which is longer than the specified 400
# Created a chunk of size 873, which is longer than the specified 400
# Created a chunk of size 2009, which is longer than the specified 400
# Created a chunk of size 2286, which is longer than the specified 400
# Created a chunk of size 1004, which is longer than the specified 400
# Created a chunk of size 578, which is longer than the specified 400
# Created a chunk of size 1143, which is longer than the specified 400
# Created a chunk of size 558, which is longer than the specified 400
# Created a chunk of size 1144, which is longer than the specified 400
# Created a chunk of size 1087, which is longer than the specified 400
# Created a chunk of size 1484, which is longer than the specified 400
# Created a chunk of size 1136, which is longer than the specified 400
# Created a chunk of size 723, which is longer than the specified 400
# Created a chunk of size 669, which is longer than the specified 400
# Created a chunk of size 766, which is longer than the specified 400
# Created a chunk of size 607, which is longer than the specified 400
# Created a chunk of size 571, which is longer than the specified 400
# Created a chunk of size 966, which is longer than the specified 400
# Created a chunk of size 858, which is longer than the specified 400
# Created a chunk of size 1033, which is longer than the specified 400
# Created a chunk of size 496, which is longer than the specified 400
# Created a chunk of size 653, which is longer than the specified 400
# Created a chunk of size 734, which is longer than the specified 400
# Created a chunk of size 526, which is longer than the specified 400
# Created a chunk of size 1016, which is longer than the specified 400
# Created a chunk of size 971, which is longer than the specified 400
# Created a chunk of size 689, which is longer than the specified 400
# Created a chunk of size 545, which is longer than the specified 400
# Created a chunk of size 932, which is longer than the specified 400
# Created a chunk of size 565, which is longer than the specified 400
# Created a chunk of size 855, which is longer than the specified 400
# Created a chunk of size 716, which is longer than the specified 400
# Created a chunk of size 750, which is longer than the specified 400
# Created a chunk of size 713, which is longer than the specified 400
# Created a chunk of size 1089, which is longer than the specified 400
# Created a chunk of size 724, which is longer than the specified 400
# Created a chunk of size 705, which is longer than the specified 400
# Created a chunk of size 1913, which is longer than the specified 400
# Created a chunk of size 486, which is longer than the specified 400
# Created a chunk of size 623, which is longer than the specified 400
# Created a chunk of size 560, which is longer than the specified 400
# Created a chunk of size 557, which is longer than the specified 400
# Created a chunk of size 426, which is longer than the specified 400
# Created a chunk of size 419, which is longer than the specified 400
# Created a chunk of size 625, which is longer than the specified 400
# Created a chunk of size 2617, which is longer than the specified 400
# Created a chunk of size 1581, which is longer than the specified 400
# Created a chunk of size 995, which is longer than the specified 400
# Created a chunk of size 848, which is longer than the specified 400
# Created a chunk of size 1531, which is longer than the specified 400
# Created a chunk of size 2031, which is longer than the specified 400
# Created a chunk of size 1620, which is longer than the specified 400
# Created a chunk of size 699, which is longer than the specified 400
# Created a chunk of size 823, which is longer than the specified 400
# Created a chunk of size 844, which is longer than the specified 400
# Created a chunk of size 1190, which is longer than the specified 400
# Created a chunk of size 509, which is longer than the specified 400
# Created a chunk of size 664, which is longer than the specified 400
# Created a chunk of size 1283, which is longer than the specified 400
# Created a chunk of size 1269, which is longer than the specified 400
# Created a chunk of size 1278, which is longer than the specified 400
# Created a chunk of size 1057, which is longer than the specified 400
# Created a chunk of size 785, which is longer than the specified 400
# Created a chunk of size 970, which is longer than the specified 400
# Created a chunk of size 614, which is longer than the specified 400
# Created a chunk of size 758, which is longer than the specified 400
# Created a chunk of size 964, which is longer than the specified 400
# Created a chunk of size 844, which is longer than the specified 400
# Created a chunk of size 787, which is longer than the specified 400
# Created a chunk of size 649, which is longer than the specified 400
# Created a chunk of size 985, which is longer than the specified 400
# Created a chunk of size 800, which is longer than the specified 400
# Created a chunk of size 1164, which is longer than the specified 400
# Created a chunk of size 1059, which is longer than the specified 400
# Created a chunk of size 876, which is longer than the specified 400
# Created a chunk of size 818, which is longer than the specified 400
# Created a chunk of size 756, which is longer than the specified 400
# Created a chunk of size 570, which is longer than the specified 400
# Created a chunk of size 629, which is longer than the specified 400
# Created a chunk of size 869, which is longer than the specified 400
# Created a chunk of size 621, which is longer than the specified 400
# Created a chunk of size 622, which is longer than the specified 400
# Created a chunk of size 1085, which is longer than the specified 400
# Created a chunk of size 2763, which is longer than the specified 400
# Created a chunk of size 1034, which is longer than the specified 400
# Created a chunk of size 759, which is longer than the specified 400
# Created a chunk of size 774, which is longer than the specified 400
# Created a chunk of size 635, which is longer than the specified 400
# Created a chunk of size 1011, which is longer than the specified 400
# Created a chunk of size 1065, which is longer than the specified 400
# Created a chunk of size 493, which is longer than the specified 400
# Created a chunk of size 796, which is longer than the specified 400
# Created a chunk of size 700, which is longer than the specified 400
# Created a chunk of size 486, which is longer than the specified 400
# Created a chunk of size 1225, which is longer than the specified 400
# Created a chunk of size 658, which is longer than the specified 400
# Created a chunk of size 768, which is longer than the specified 400
# Created a chunk of size 554, which is longer than the specified 400
# Created a chunk of size 591, which is longer than the specified 400
# Created a chunk of size 727, which is longer than the specified 400
# Created a chunk of size 1806, which is longer than the specified 400
# Created a chunk of size 1018, which is longer than the specified 400
# Created a chunk of size 685, which is longer than the specified 400
# Created a chunk of size 740, which is longer than the specified 400
# Created a chunk of size 450, which is longer than the specified 400
# Created a chunk of size 473, which is longer than the specified 400
# Created a chunk of size 923, which is longer than the specified 400
# Created a chunk of size 968, which is longer than the specified 400
# Created a chunk of size 478, which is longer than the specified 400
# Created a chunk of size 646, which is longer than the specified 400
# Created a chunk of size 677, which is longer than the specified 400
# Created a chunk of size 713, which is longer than the specified 400
# Created a chunk of size 800, which is longer than the specified 400
# Created a chunk of size 855, which is longer than the specified 400
# Created a chunk of size 671, which is longer than the specified 400
# Created a chunk of size 855, which is longer than the specified 400
# Created a chunk of size 761, which is longer than the specified 400
# Created a chunk of size 797, which is longer than the specified 400
# Created a chunk of size 680, which is longer than the specified 400
# Created a chunk of size 928, which is longer than the specified 400
# Created a chunk of size 1269, which is longer than the specified 400
# Created a chunk of size 734, which is longer than the specified 400
# Created a chunk of size 869, which is longer than the specified 400
# Created a chunk of size 932, which is longer than the specified 400
# Created a chunk of size 773, which is longer than the specified 400
# Created a chunk of size 771, which is longer than the specified 400
# Created a chunk of size 650, which is longer than the specified 400
# Created a chunk of size 1772, which is longer than the specified 400
# Created a chunk of size 535, which is longer than the specified 400
# Created a chunk of size 825, which is longer than the specified 400
# Created a chunk of size 600, which is longer than the specified 400
# Created a chunk of size 487, which is longer than the specified 400
# Created a chunk of size 970, which is longer than the specified 400
# Created a chunk of size 555, which is longer than the specified 400
# Created a chunk of size 492, which is longer than the specified 400
# Created a chunk of size 845, which is longer than the specified 400
# Created a chunk of size 877, which is longer than the specified 400
# Created a chunk of size 671, which is longer than the specified 400
# Created a chunk of size 708, which is longer than the specified 400
# Created a chunk of size 655, which is longer than the specified 400
# Created a chunk of size 1271, which is longer than the specified 400
# Created a chunk of size 737, which is longer than the specified 400
# Created a chunk of size 1020, which is longer than the specified 400
# Created a chunk of size 778, which is longer than the specified 400
# Created a chunk of size 683, which is longer than the specified 400
# Created a chunk of size 599, which is longer than the specified 400
# Created a chunk of size 664, which is longer than the specified 400
# Created a chunk of size 596, which is longer than the specified 400
# Created a chunk of size 858, which is longer than the specified 400
# Created a chunk of size 596, which is longer than the specified 400
# Created a chunk of size 538, which is longer than the specified 400
# Created a chunk of size 568, which is longer than the specified 400
# Created a chunk of size 706, which is longer than the specified 400
# Created a chunk of size 849, which is longer than the specified 400
# Created a chunk of size 543, which is longer than the specified 400
# Created a chunk of size 1178, which is longer than the specified 400
# Created a chunk of size 459, which is longer than the specified 400
# Created a chunk of size 905, which is longer than the specified 400
# Created a chunk of size 853, which is longer than the specified 400
# Created a chunk of size 508, which is longer than the specified 400
# Created a chunk of size 1716, which is longer than the specified 400
# Created a chunk of size 846, which is longer than the specified 400
# Created a chunk of size 1682, which is longer than the specified 400
# Created a chunk of size 722, which is longer than the specified 400
# Created a chunk of size 660, which is longer than the specified 400
# Created a chunk of size 604, which is longer than the specified 400
# Created a chunk of size 992, which is longer than the specified 400
# Created a chunk of size 1129, which is longer than the specified 400
# Created a chunk of size 463, which is longer than the specified 400
# Created a chunk of size 2006, which is longer than the specified 400
# Created a chunk of size 1172, which is longer than the specified 400
# Created a chunk of size 2142, which is longer than the specified 400
# Created a chunk of size 663, which is longer than the specified 400
# Created a chunk of size 1323, which is longer than the specified 400
# Created a chunk of size 527, which is longer than the specified 400
# Created a chunk of size 1113, which is longer than the specified 400
# Created a chunk of size 665, which is longer than the specified 400
# Created a chunk of size 909, which is longer than the specified 400
# Created a chunk of size 1317, which is longer than the specified 400
# Created a chunk of size 692, which is longer than the specified 400
# Created a chunk of size 951, which is longer than the specified 400
# Created a chunk of size 1122, which is longer than the specified 400
# Created a chunk of size 777, which is longer than the specified 400
# Created a chunk of size 616, which is longer than the specified 400
# Created a chunk of size 424, which is longer than the specified 400
# Created a chunk of size 534, which is longer than the specified 400
# Created a chunk of size 1019, which is longer than the specified 400
# Created a chunk of size 726, which is longer than the specified 400
# Created a chunk of size 613, which is longer than the specified 400
# Created a chunk of size 630, which is longer than the specified 400
# Created a chunk of size 464, which is longer than the specified 400
# Created a chunk of size 1008, which is longer than the specified 400
# Created a chunk of size 617, which is longer than the specified 400
# Created a chunk of size 885, which is longer than the specified 400
# Created a chunk of size 580, which is longer than the specified 400
# Created a chunk of size 912, which is longer than the specified 400
# Created a chunk of size 1058, which is longer than the specified 400
# Created a chunk of size 631, which is longer than the specified 400
# Created a chunk of size 1256, which is longer than the specified 400
# Created a chunk of size 573, which is longer than the specified 400
# Created a chunk of size 1099, which is longer than the specified 400
# Created a chunk of size 908, which is longer than the specified 400
# Created a chunk of size 622, which is longer than the specified 400
# Created a chunk of size 410, which is longer than the specified 400
# Created a chunk of size 449, which is longer than the specified 400
# Created a chunk of size 878, which is longer than the specified 400
# Created a chunk of size 1144, which is longer than the specified 400
# Created a chunk of size 878, which is longer than the specified 400
# Created a chunk of size 621, which is longer than the specified 400
# Created a chunk of size 626, which is longer than the specified 400
# Created a chunk of size 552, which is longer than the specified 400
# Created a chunk of size 842, which is longer than the specified 400
# Created a chunk of size 482, which is longer than the specified 400
# Created a chunk of size 715, which is longer than the specified 400
# Created a chunk of size 922, which is longer than the specified 400
# Created a chunk of size 582, which is longer than the specified 400
# Created a chunk of size 745, which is longer than the specified 400
# Created a chunk of size 555, which is longer than the specified 400
# Created a chunk of size 801, which is longer than the specified 400
# Created a chunk of size 542, which is longer than the specified 400
# Created a chunk of size 751, which is longer than the specified 400
# Created a chunk of size 613, which is longer than the specified 400
# Created a chunk of size 496, which is longer than the specified 400
# Created a chunk of size 612, which is longer than the specified 400
# Created a chunk of size 588, which is longer than the specified 400
# Created a chunk of size 810, which is longer than the specified 400
# Created a chunk of size 600, which is longer than the specified 400
# Created a chunk of size 1551, which is longer than the specified 400
# Created a chunk of size 591, which is longer than the specified 400
# Created a chunk of size 828, which is longer than the specified 400
# Created a chunk of size 665, which is longer than the specified 400
# Created a chunk of size 878, which is longer than the specified 400
# Created a chunk of size 737, which is longer than the specified 400
# Created a chunk of size 430, which is longer than the specified 400
# Created a chunk of size 724, which is longer than the specified 400
# Created a chunk of size 508, which is longer than the specified 400
# Created a chunk of size 423, which is longer than the specified 400
# Created a chunk of size 924, which is longer than the specified 400
# Created a chunk of size 548, which is longer than the specified 400
# Created a chunk of size 1653, which is longer than the specified 400
# Created a chunk of size 874, which is longer than the specified 400
# Created a chunk of size 1496, which is longer than the specified 400
# Created a chunk of size 475, which is longer than the specified 400
# Created a chunk of size 737, which is longer than the specified 400
# Created a chunk of size 528, which is longer than the specified 400
# Created a chunk of size 613, which is longer than the specified 400
# Created a chunk of size 800, which is longer than the specified 400
# Created a chunk of size 437, which is longer than the specified 400
# Created a chunk of size 539, which is longer than the specified 400
# Created a chunk of size 546, which is longer than the specified 400
# Created a chunk of size 462, which is longer than the specified 400
# Created a chunk of size 474, which is longer than the specified 400
# Created a chunk of size 724, which is longer than the specified 400
# Created a chunk of size 977, which is longer than the specified 400
# Created a chunk of size 927, which is longer than the specified 400
# Created a chunk of size 555, which is longer than the specified 400
# Created a chunk of size 675, which is longer than the specified 400
# Created a chunk of size 790, which is longer than the specified 400
# Created a chunk of size 637, which is longer than the specified 400
# Created a chunk of size 417, which is longer than the specified 400
# Created a chunk of size 616, which is longer than the specified 400
# Created a chunk of size 992, which is longer than the specified 400
# Created a chunk of size 449, which is longer than the specified 400
# Created a chunk of size 677, which is longer than the specified 400
# Created a chunk of size 451, which is longer than the specified 400
# Created a chunk of size 582, which is longer than the specified 400
# Created a chunk of size 584, which is longer than the specified 400
# Created a chunk of size 776, which is longer than the specified 400
# Created a chunk of size 531, which is longer than the specified 400
# Created a chunk of size 614, which is longer than the specified 400
# Created a chunk of size 833, which is longer than the specified 400
# Created a chunk of size 435, which is longer than the specified 400
# Created a chunk of size 825, which is longer than the specified 400
# Created a chunk of size 466, which is longer than the specified 400
# Created a chunk of size 887, which is longer than the specified 400
# Created a chunk of size 1278, which is longer than the specified 400
# Created a chunk of size 667, which is longer than the specified 400
# Created a chunk of size 848, which is longer than the specified 400
# Created a chunk of size 1047, which is longer than the specified 400
# Created a chunk of size 671, which is longer than the specified 400
# Created a chunk of size 466, which is longer than the specified 400
# Created a chunk of size 555, which is longer than the specified 400
# Created a chunk of size 915, which is longer than the specified 400
# Created a chunk of size 756, which is longer than the specified 400
# Created a chunk of size 758, which is longer than the specified 400
# Created a chunk of size 946, which is longer than the specified 400
# Created a chunk of size 906, which is longer than the specified 400
# Created a chunk of size 848, which is longer than the specified 400
# Created a chunk of size 866, which is longer than the specified 400
# Created a chunk of size 803, which is longer than the specified 400
# Created a chunk of size 838, which is longer than the specified 400
# Created a chunk of size 755, which is longer than the specified 400
# Created a chunk of size 865, which is longer than the specified 400
# Created a chunk of size 800, which is longer than the specified 400
# Created a chunk of size 679, which is longer than the specified 400
# Created a chunk of size 514, which is longer than the specified 400
# Created a chunk of size 543, which is longer than the specified 400
# Created a chunk of size 817, which is longer than the specified 400
# Created a chunk of size 744, which is longer than the specified 400
# Created a chunk of size 673, which is longer than the specified 400
# Created a chunk of size 671, which is longer than the specified 400
# Created a chunk of size 477, which is longer than the specified 400
# Created a chunk of size 991, which is longer than the specified 400
# Created a chunk of size 768, which is longer than the specified 400
# Created a chunk of size 407, which is longer than the specified 400
# Created a chunk of size 995, which is longer than the specified 400
# Created a chunk of size 573, which is longer than the specified 400
# Created a chunk of size 475, which is longer than the specified 400
# Created a chunk of size 640, which is longer than the specified 400
# Created a chunk of size 608, which is longer than the specified 400
# Created a chunk of size 1667, which is longer than the specified 400
# Created a chunk of size 1617, which is longer than the specified 400
# Created a chunk of size 779, which is longer than the specified 400
# Created a chunk of size 575, which is longer than the specified 400
# Created a chunk of size 670, which is longer than the specified 400
# Created a chunk of size 817, which is longer than the specified 400
# Created a chunk of size 443, which is longer than the specified 400
# Created a chunk of size 521, which is longer than the specified 400
# Created a chunk of size 488, which is longer than the specified 400
# Created a chunk of size 608, which is longer than the specified 400
# Created a chunk of size 734, which is longer than the specified 400
# Created a chunk of size 1096, which is longer than the specified 400
# Created a chunk of size 1598, which is longer than the specified 400
# Created a chunk of size 945, which is longer than the specified 400
# Created a chunk of size 1961, which is longer than the specified 400
# Created a chunk of size 596, which is longer than the specified 400
# Created a chunk of size 1709, which is longer than the specified 400
# Created a chunk of size 896, which is longer than the specified 400
# Created a chunk of size 635, which is longer than the specified 400
# Created a chunk of size 995, which is longer than the specified 400
# Created a chunk of size 1948, which is longer than the specified 400
# Created a chunk of size 1028, which is longer than the specified 400
# Created a chunk of size 617, which is longer than the specified 400
# Created a chunk of size 495, which is longer than the specified 400
# Created a chunk of size 467, which is longer than the specified 400
# Created a chunk of size 1808, which is longer than the specified 400
# Created a chunk of size 618, which is longer than the specified 400
# Created a chunk of size 401, which is longer than the specified 400
# Created a chunk of size 643, which is longer than the specified 400
# Created a chunk of size 1519, which is longer than the specified 400
# Created a chunk of size 754, which is longer than the specified 400
# Created a chunk of size 617, which is longer than the specified 400
# Created a chunk of size 460, which is longer than the specified 400
# Created a chunk of size 689, which is longer than the specified 400
# Created a chunk of size 810, which is longer than the specified 400
# Created a chunk of size 537, which is longer than the specified 400
# Created a chunk of size 870, which is longer than the specified 400
# Created a chunk of size 484, which is longer than the specified 400
# Created a chunk of size 891, which is longer than the specified 400
# Created a chunk of size 560, which is longer than the specified 400
# Created a chunk of size 1088, which is longer than the specified 400
# Created a chunk of size 417, which is longer than the specified 400
# Created a chunk of size 731, which is longer than the specified 400
# Created a chunk of size 533, which is longer than the specified 400
# Created a chunk of size 616, which is longer than the specified 400
# Created a chunk of size 401, which is longer than the specified 400
# Created a chunk of size 1094, which is longer than the specified 400
# Created a chunk of size 436, which is longer than the specified 400
# Created a chunk of size 408, which is longer than the specified 400
# Created a chunk of size 408, which is longer than the specified 400
# Created a chunk of size 879, which is longer than the specified 400
# Created a chunk of size 980, which is longer than the specified 400
# Created a chunk of size 989, which is longer than the specified 400
# Created a chunk of size 536, which is longer than the specified 400
# Created a chunk of size 1168, which is longer than the specified 400
# Created a chunk of size 1260, which is longer than the specified 400
# Created a chunk of size 1481, which is longer than the specified 400
# Created a chunk of size 817, which is longer than the specified 400
# Created a chunk of size 1038, which is longer than the specified 400
# Created a chunk of size 1086, which is longer than the specified 400
# Created a chunk of size 1444, which is longer than the specified 400
# Created a chunk of size 1267, which is longer than the specified 400
# Created a chunk of size 1145, which is longer than the specified 400
# Created a chunk of size 1370, which is longer than the specified 400
# Created a chunk of size 1623, which is longer than the specified 400
# Created a chunk of size 1166, which is longer than the specified 400
# Created a chunk of size 584, which is longer than the specified 400
# Created a chunk of size 784, which is longer than the specified 400
# Created a chunk of size 1177, which is longer than the specified 400
# Created a chunk of size 1180, which is longer than the specified 400
# Created a chunk of size 731, which is longer than the specified 400
# Created a chunk of size 827, which is longer than the specified 400
# Created a chunk of size 596, which is longer than the specified 400
# Created a chunk of size 999, which is longer than the specified 400
# Created a chunk of size 461, which is longer than the specified 400
# Created a chunk of size 1010, which is longer than the specified 400
# Created a chunk of size 664, which is longer than the specified 400
# Created a chunk of size 1023, which is longer than the specified 400
# Created a chunk of size 746, which is longer than the specified 400
# Created a chunk of size 1358, which is longer than the specified 400
# Created a chunk of size 814, which is longer than the specified 400
# Created a chunk of size 425, which is longer than the specified 400
# Created a chunk of size 1173, which is longer than the specified 400
# Created a chunk of size 1395, which is longer than the specified 400
# Created a chunk of size 1217, which is longer than the specified 400
# Created a chunk of size 464, which is longer than the specified 400
# Created a chunk of size 422, which is longer than the specified 400
# Created a chunk of size 604, which is longer than the specified 400
# Created a chunk of size 2210, which is longer than the specified 400
# Created a chunk of size 1372, which is longer than the specified 400
# Created a chunk of size 2878, which is longer than the specified 400
# Created a chunk of size 794, which is longer than the specified 400
# Created a chunk of size 790, which is longer than the specified 400
# Created a chunk of size 1280, which is longer than the specified 400
# Created a chunk of size 778, which is longer than the specified 400
# Created a chunk of size 1715, which is longer than the specified 400
# Created a chunk of size 1639, which is longer than the specified 400
# Created a chunk of size 757, which is longer than the specified 400
# Created a chunk of size 512, which is longer than the specified 400
# Created a chunk of size 518, which is longer than the specified 400
# Created a chunk of size 2399, which is longer than the specified 400
# Created a chunk of size 826, which is longer than the specified 400
# Created a chunk of size 2121, which is longer than the specified 400
# Created a chunk of size 1489, which is longer than the specified 400
# Created a chunk of size 427, which is longer than the specified 400
# Created a chunk of size 1692, which is longer than the specified 400
# Created a chunk of size 766, which is longer than the specified 400
# Created a chunk of size 844, which is longer than the specified 400
# Created a chunk of size 1419, which is longer than the specified 400
# Created a chunk of size 792, which is longer than the specified 400
# Created a chunk of size 1174, which is longer than the specified 400
# Created a chunk of size 1360, which is longer than the specified 400
# Created a chunk of size 459, which is longer than the specified 400
# Created a chunk of size 827, which is longer than the specified 400
# Created a chunk of size 916, which is longer than the specified 400
# Created a chunk of size 435, which is longer than the specified 400
# Created a chunk of size 2182, which is longer than the specified 400
# Created a chunk of size 1094, which is longer than the specified 400
# Created a chunk of size 2172, which is longer than the specified 400
# Created a chunk of size 1455, which is longer than the specified 400
# Created a chunk of size 1455, which is longer than the specified 400
# Created a chunk of size 583, which is longer than the specified 400
# Created a chunk of size 1974, which is longer than the specified 400
# Created a chunk of size 1988, which is longer than the specified 400
# Created a chunk of size 1649, which is longer than the specified 400
# Created a chunk of size 2724, which is longer than the specified 400
# Created a chunk of size 1633, which is longer than the specified 400
# Created a chunk of size 477, which is longer than the specified 400
# Created a chunk of size 939, which is longer than the specified 400
# Created a chunk of size 504, which is longer than the specified 400
# Created a chunk of size 1285, which is longer than the specified 400
# Created a chunk of size 1485, which is longer than the specified 400
# Created a chunk of size 693, which is longer than the specified 400
# Created a chunk of size 1050, which is longer than the specified 400
# Created a chunk of size 468, which is longer than the specified 400
# Created a chunk of size 412, which is longer than the specified 400
# Created a chunk of size 1004, which is longer than the specified 400
# Created a chunk of size 1151, which is longer than the specified 400
# Created a chunk of size 452, which is longer than the specified 400
# Created a chunk of size 1217, which is longer than the specified 400
# Created a chunk of size 900, which is longer than the specified 400
# Created a chunk of size 611, which is longer than the specified 400
# Created a chunk of size 412, which is longer than the specified 400
# Created a chunk of size 946, which is longer than the specified 400
# Created a chunk of size 1033, which is longer than the specified 400
# Created a chunk of size 2457, which is longer than the specified 400
# Created a chunk of size 984, which is longer than the specified 400
# Created a chunk of size 1350, which is longer than the specified 400
# Created a chunk of size 1272, which is longer than the specified 400
# Created a chunk of size 1118, which is longer than the specified 400
# Created a chunk of size 1549, which is longer than the specified 400
# Created a chunk of size 1202, which is longer than the specified 400
# Created a chunk of size 553, which is longer than the specified 400
# Created a chunk of size 503, which is longer than the specified 400
# Created a chunk of size 758, which is longer than the specified 400
# Created a chunk of size 976, which is longer than the specified 400
# Created a chunk of size 542, which is longer than the specified 400
# Created a chunk of size 997, which is longer than the specified 400
# Created a chunk of size 1161, which is longer than the specified 400
# Created a chunk of size 621, which is longer than the specified 400
# Created a chunk of size 723, which is longer than the specified 400
# Created a chunk of size 592, which is longer than the specified 400
# Created a chunk of size 1150, which is longer than the specified 400
# Created a chunk of size 408, which is longer than the specified 400
# Created a chunk of size 838, which is longer than the specified 400
# Created a chunk of size 965, which is longer than the specified 400
# Created a chunk of size 1025, which is longer than the specified 400
# Created a chunk of size 1775, which is longer than the specified 400
# Created a chunk of size 1166, which is longer than the specified 400
# Created a chunk of size 540, which is longer than the specified 400
# Created a chunk of size 1010, which is longer than the specified 400
# Created a chunk of size 578, which is longer than the specified 400
# Created a chunk of size 754, which is longer than the specified 400
# Created a chunk of size 428, which is longer than the specified 400
# Created a chunk of size 432, which is longer than the specified 400
# Created a chunk of size 1018, which is longer than the specified 400
# Created a chunk of size 1324, which is longer than the specified 400
# Created a chunk of size 1214, which is longer than the specified 400
# Created a chunk of size 910, which is longer than the specified 400
# Created a chunk of size 465, which is longer than the specified 400
# Created a chunk of size 664, which is longer than the specified 400
# Created a chunk of size 754, which is longer than the specified 400
# Created a chunk of size 557, which is longer than the specified 400
# Created a chunk of size 1124, which is longer than the specified 400
# Created a chunk of size 608, which is longer than the specified 400
# Created a chunk of size 458, which is longer than the specified 400
# Created a chunk of size 1599, which is longer than the specified 400
# Created a chunk of size 494, which is longer than the specified 400
# Created a chunk of size 1964, which is longer than the specified 400
# Created a chunk of size 895, which is longer than the specified 400
# Created a chunk of size 692, which is longer than the specified 400
# Created a chunk of size 510, which is longer than the specified 400
# Created a chunk of size 941, which is longer than the specified 400
# Created a chunk of size 2451, which is longer than the specified 400
# Created a chunk of size 1797, which is longer than the specified 400
# Created a chunk of size 1569, which is longer than the specified 400
# Created a chunk of size 1220, which is longer than the specified 400
# Created a chunk of size 758, which is longer than the specified 400
# Created a chunk of size 881, which is longer than the specified 400
# Created a chunk of size 1381, which is longer than the specified 400
# Created a chunk of size 402, which is longer than the specified 400
# Created a chunk of size 855, which is longer than the specified 400
# Created a chunk of size 1453, which is longer than the specified 400
# Created a chunk of size 1103, which is longer than the specified 400
# Created a chunk of size 401, which is longer than the specified 400
# Created a chunk of size 407, which is longer than the specified 400
# Created a chunk of size 1299, which is longer than the specified 400
# Created a chunk of size 493, which is longer than the specified 400
# Created a chunk of size 777, which is longer than the specified 400
# Created a chunk of size 908, which is longer than the specified 400
# Created a chunk of size 994, which is longer than the specified 400
# Created a chunk of size 774, which is longer than the specified 400
# Created a chunk of size 1762, which is longer than the specified 400
# Created a chunk of size 1005, which is longer than the specified 400
# Created a chunk of size 1023, which is longer than the specified 400
# Created a chunk of size 769, which is longer than the specified 400
# Created a chunk of size 657, which is longer than the specified 400
# Created a chunk of size 466, which is longer than the specified 400
# Created a chunk of size 585, which is longer than the specified 400
# Created a chunk of size 641, which is longer than the specified 400
# Created a chunk of size 732, which is longer than the specified 400
# Created a chunk of size 635, which is longer than the specified 400
# Created a chunk of size 924, which is longer than the specified 400
# Created a chunk of size 1065, which is longer than the specified 400
# Created a chunk of size 869, which is longer than the specified 400
# Created a chunk of size 1010, which is longer than the specified 400
# Created a chunk of size 881, which is longer than the specified 400
# Created a chunk of size 766, which is longer than the specified 400
# Created a chunk of size 989, which is longer than the specified 400
# Created a chunk of size 789, which is longer than the specified 400
# Created a chunk of size 724, which is longer than the specified 400
# Created a chunk of size 1065, which is longer than the specified 400
# Created a chunk of size 1630, which is longer than the specified 400
# Created a chunk of size 1594, which is longer than the specified 400
# Created a chunk of size 624, which is longer than the specified 400
# Created a chunk of size 826, which is longer than the specified 400
# Created a chunk of size 1588, which is longer than the specified 400
# Created a chunk of size 406, which is longer than the specified 400
# Created a chunk of size 572, which is longer than the specified 400
# Created a chunk of size 1260, which is longer than the specified 400
# Created a chunk of size 1129, which is longer than the specified 400
# Created a chunk of size 1106, which is longer than the specified 400
# Created a chunk of size 482, which is longer than the specified 400
# Created a chunk of size 849, which is longer than the specified 400
# Created a chunk of size 793, which is longer than the specified 400
# Created a chunk of size 783, which is longer than the specified 400
# Created a chunk of size 658, which is longer than the specified 400
# Created a chunk of size 950, which is longer than the specified 400
# Created a chunk of size 477, which is longer than the specified 400
# Created a chunk of size 848, which is longer than the specified 400
# Created a chunk of size 759, which is longer than the specified 400
# Created a chunk of size 972, which is longer than the specified 400
# Created a chunk of size 684, which is longer than the specified 400
# Created a chunk of size 1081, which is longer than the specified 400
# Created a chunk of size 1534, which is longer than the specified 400
# Created a chunk of size 791, which is longer than the specified 400
# Created a chunk of size 824, which is longer than the specified 400
# Created a chunk of size 1203, which is longer than the specified 400
# Created a chunk of size 1094, which is longer than the specified 400
# Created a chunk of size 1248, which is longer than the specified 400
# Created a chunk of size 1057, which is longer than the specified 400
# Created a chunk of size 669, which is longer than the specified 400
# Created a chunk of size 510, which is longer than the specified 400
# Created a chunk of size 1212, which is longer than the specified 400
# Created a chunk of size 551, which is longer than the specified 400
# Created a chunk of size 931, which is longer than the specified 400
# Created a chunk of size 1012, which is longer than the specified 400
# Created a chunk of size 997, which is longer than the specified 400
# Created a chunk of size 548, which is longer than the specified 400
# Created a chunk of size 1353, which is longer than the specified 400
# Created a chunk of size 1413, which is longer than the specified 400
# Created a chunk of size 878, which is longer than the specified 400
# Created a chunk of size 1024, which is longer than the specified 400
# Created a chunk of size 1217, which is longer than the specified 400
# Created a chunk of size 837, which is longer than the specified 400
# Created a chunk of size 1132, which is longer than the specified 400
# ...
# Created a chunk of size 486, which is longer than the specified 400
# Created a chunk of size 461, which is longer than the specified 400
# Created a chunk of size 1773, which is longer than the specified 400
# Created a chunk of size 1503, which is longer than the specified 400
# Created a chunk of size 563, which is longer than the specified 400
# Created a chunk of size 444, which is longer than the specified 400
# Created a chunk of size 422, which is longer than the specified 400
# Created a chunk of size 417, which is longer than the specified 400
# Created a chunk of size 1545, which is longer than the specified 400
# Created a chunk of size 2856, which is longer than the specified 400
# Created a chunk of size 601, which is longer than the specified 400
# Created a chunk of size 567, which is longer than the specified 400
# Created a chunk of size 712, which is longer than the specified 400
# Created a chunk of size 419, which is longer than the specified 400
# Created a chunk of size 1091, which is longer than the specified 400
# Created a chunk of size 964, which is longer than the specified 400
# Created a chunk of size 1133, which is longer than the specified 400
# Created a chunk of size 763, which is longer than the specified 400
# Created a chunk of size 1198, which is longer than the specified 400
# Created a chunk of size 1173, which is longer than the specified 400
# Created a chunk of size 962, which is longer than the specified 400
# Created a chunk of size 1215, which is longer than the specified 400
# Created a chunk of size 967, which is longer than the specified 400
# Created a chunk of size 882, which is longer than the specified 400
# Created a chunk of size 1003, which is longer than the specified 400
# Created a chunk of size 405, which is longer than the specified 400
# Created a chunk of size 1473, which is longer than the specified 400
# Created a chunk of size 1472, which is longer than the specified 400
# Created a chunk of size 886, which is longer than the specified 400
# Created a chunk of size 521, which is longer than the specified 400
# Created a chunk of size 500, which is longer than the specified 400
# Created a chunk of size 1216, which is longer than the specified 400
# Created a chunk of size 944, which is longer than the specified 400
# Created a chunk of size 1863, which is longer than the specified 400
# Created a chunk of size 423, which is longer than the specified 400
# Created a chunk of size 1526, which is longer than the specified 400
# Created a chunk of size 1017, which is longer than the specified 400
# Created a chunk of size 1386, which is longer than the specified 400
# Created a chunk of size 435, which is longer than the specified 400
# Created a chunk of size 1453, which is longer than the specified 400
# Created a chunk of size 1166, which is longer than the specified 400
# Created a chunk of size 928, which is longer than the specified 400
# Created a chunk of size 882, which is longer than the specified 400
# Created a chunk of size 500, which is longer than the specified 400
# Created a chunk of size 814, which is longer than the specified 400
# Created a chunk of size 946, which is longer than the specified 400
# Created a chunk of size 1004, which is longer than the specified 400
# Created a chunk of size 1361, which is longer than the specified 400
# Created a chunk of size 924, which is longer than the specified 400
# Created a chunk of size 1342, which is longer than the specified 400
# Created a chunk of size 835, which is longer than the specified 400
# Created a chunk of size 531, which is longer than the specified 400
# Created a chunk of size 1051, which is longer than the specified 400
# Created a chunk of size 571, which is longer than the specified 400
# Created a chunk of size 1339, which is longer than the specified 400
# Created a chunk of size 497, which is longer than the specified 400
# Created a chunk of size 1602, which is longer than the specified 400
# Created a chunk of size 1058, which is longer than the specified 400
# Created a chunk of size 1268, which is longer than the specified 400
# Created a chunk of size 405, which is longer than the specified 400
# Created a chunk of size 770, which is longer than the specified 400
# Created a chunk of size 1027, which is longer than the specified 400
# Created a chunk of size 528, which is longer than the specified 400
# Created a chunk of size 727, which is longer than the specified 400
# Created a chunk of size 676, which is longer than the specified 400
# Created a chunk of size 824, which is longer than the specified 400
# Created a chunk of size 832, which is longer than the specified 400
# Created a chunk of size 573, which is longer than the specified 400
# Created a chunk of size 1037, which is longer than the specified 400
# Created a chunk of size 741, which is longer than the specified 400
# Created a chunk of size 574, which is longer than the specified 400
# Created a chunk of size 898, which is longer than the specified 400
# Created a chunk of size 1433, which is longer than the specified 400
# Created a chunk of size 874, which is longer than the specified 400
# Created a chunk of size 2870, which is longer than the specified 400
# Created a chunk of size 2348, which is longer than the specified 400
# Created a chunk of size 529, which is longer than the specified 400
# Created a chunk of size 2452, which is longer than the specified 400
# Created a chunk of size 902, which is longer than the specified 400
# Created a chunk of size 757, which is longer than the specified 400
# Created a chunk of size 401, which is longer than the specified 400
# Created a chunk of size 1055, which is longer than the specified 400
# Created a chunk of size 1511, which is longer than the specified 400
# Created a chunk of size 922, which is longer than the specified 400
# Created a chunk of size 1114, which is longer than the specified 400
# Created a chunk of size 1110, which is longer than the specified 400
# Created a chunk of size 771, which is longer than the specified 400
# Created a chunk of size 739, which is longer than the specified 400
# Created a chunk of size 923, which is longer than the specified 400
# Created a chunk of size 722, which is longer than the specified 400
# Created a chunk of size 927, which is longer than the specified 400
# Created a chunk of size 631, which is longer than the specified 400
# Created a chunk of size 401, which is longer than the specified 400
# Created a chunk of size 1513, which is longer than the specified 400
# Created a chunk of size 1301, which is longer than the specified 400
# Created a chunk of size 602, which is longer than the specified 400
# Created a chunk of size 798, which is longer than the specified 400
# Created a chunk of size 432, which is longer than the specified 400
# Created a chunk of size 432, which is longer than the specified 400
# Created a chunk of size 840, which is longer than the specified 400
# Created a chunk of size 432, which is longer than the specified 400
# Created a chunk of size 798, which is longer than the specified 400
# Created a chunk of size 1135, which is longer than the specified 400
# Created a chunk of size 509, which is longer than the specified 400
# Created a chunk of size 1349, which is longer than the specified 400
# Created a chunk of size 681, which is longer than the specified 400
# Created a chunk of size 580, which is longer than the specified 400
# Created a chunk of size 955, which is longer than the specified 400
# Created a chunk of size 684, which is longer than the specified 400
# Created a chunk of size 728, which is longer than the specified 400
# Created a chunk of size 657, which is longer than the specified 400
# Created a chunk of size 1085, which is longer than the specified 400
# Created a chunk of size 795, which is longer than the specified 400
# Created a chunk of size 799, which is longer than the specified 400
# Created a chunk of size 999, which is longer than the specified 400
# Created a chunk of size 961, which is longer than the specified 400
# Created a chunk of size 660, which is longer than the specified 400
# Created a chunk of size 757, which is longer than the specified 400
# Created a chunk of size 510, which is longer than the specified 400
# Created a chunk of size 561, which is longer than the specified 400
# Created a chunk of size 503, which is longer than the specified 400
# Created a chunk of size 671, which is longer than the specified 400
# Created a chunk of size 671, which is longer than the specified 400
# Created a chunk of size 676, which is longer than the specified 400
# Created a chunk of size 857, which is longer than the specified 400
# Created a chunk of size 1109, which is longer than the specified 400
# Created a chunk of size 541, which is longer than the specified 400
# Created a chunk of size 452, which is longer than the specified 400
# Created a chunk of size 982, which is longer than the specified 400
# Created a chunk of size 1341, which is longer than the specified 400
# Created a chunk of size 762, which is longer than the specified 400
# Created a chunk of size 420, which is longer than the specified 400
# Created a chunk of size 439, which is longer than the specified 400
# Created a chunk of size 1299, which is longer than the specified 400
# Created a chunk of size 721, which is longer than the specified 400
# Created a chunk of size 1321, which is longer than the specified 400
# Created a chunk of size 1525, which is longer than the specified 400
# Created a chunk of size 1032, which is longer than the specified 400
# Created a chunk of size 706, which is longer than the specified 400
# Created a chunk of size 1256, which is longer than the specified 400
# Created a chunk of size 711, which is longer than the specified 400
# Created a chunk of size 1126, which is longer than the specified 400
# Created a chunk of size 1294, which is longer than the specified 400
# Created a chunk of size 1042, which is longer than the specified 400
# Created a chunk of size 501, which is longer than the specified 400
# Created a chunk of size 1151, which is longer than the specified 400
# Created a chunk of size 934, which is longer than the specified 400
# Created a chunk of size 662, which is longer than the specified 400
# Created a chunk of size 881, which is longer than the specified 400
# Created a chunk of size 889, which is longer than the specified 400
# Created a chunk of size 571, which is longer than the specified 400
# Created a chunk of size 894, which is longer than the specified 400
# Created a chunk of size 529, which is longer than the specified 400
# Created a chunk of size 555, which is longer than the specified 400
# Created a chunk of size 910, which is longer than the specified 400
# Created a chunk of size 964, which is longer than the specified 400
# Created a chunk of size 869, which is longer than the specified 400
# Created a chunk of size 530, which is longer than the specified 400
# Created a chunk of size 407, which is longer than the specified 400
# Created a chunk of size 632, which is longer than the specified 400
# Created a chunk of size 484, which is longer than the specified 400
# Created a chunk of size 511, which is longer than the specified 400
# Created a chunk of size 474, which is longer than the specified 400
# Created a chunk of size 650, which is longer than the specified 400
# Created a chunk of size 462, which is longer than the specified 400
# Created a chunk of size 906, which is longer than the specified 400
# Created a chunk of size 605, which is longer than the specified 400
# Created a chunk of size 566, which is longer than the specified 400
# Created a chunk of size 668, which is longer than the specified 400
# Created a chunk of size 526, which is longer than the specified 400
# Created a chunk of size 1156, which is longer than the specified 400
# Created a chunk of size 1351, which is longer than the specified 400
# Created a chunk of size 1404, which is longer than the specified 400
# Created a chunk of size 976, which is longer than the specified 400
# Created a chunk of size 412, which is longer than the specified 400
# Created a chunk of size 414, which is longer than the specified 400
# Created a chunk of size 581, which is longer than the specified 400
# Created a chunk of size 638, which is longer than the specified 400
# Created a chunk of size 1899, which is longer than the specified 400
# Created a chunk of size 2150, which is longer than the specified 400
# Created a chunk of size 1418, which is longer than the specified 400
# Created a chunk of size 587, which is longer than the specified 400
# Created a chunk of size 974, which is longer than the specified 400
# Created a chunk of size 1420, which is longer than the specified 400
# Created a chunk of size 841, which is longer than the specified 400
# Created a chunk of size 1388, which is longer than the specified 400
# Created a chunk of size 487, which is longer than the specified 400
# Created a chunk of size 508, which is longer than the specified 400
# Created a chunk of size 1281, which is longer than the specified 400
# Created a chunk of size 1288, which is longer than the specified 400
# Created a chunk of size 678, which is longer than the specified 400
# Created a chunk of size 466, which is longer than the specified 400
# Created a chunk of size 800, which is longer than the specified 400
# Created a chunk of size 1044, which is longer than the specified 400
# Created a chunk of size 417, which is longer than the specified 400
# Created a chunk of size 2743, which is longer than the specified 400
# Created a chunk of size 867, which is longer than the specified 400
# Created a chunk of size 604, which is longer than the specified 400
# Created a chunk of size 405, which is longer than the specified 400
# Created a chunk of size 1183, which is longer than the specified 400
# Created a chunk of size 655, which is longer than the specified 400
# Created a chunk of size 1001, which is longer than the specified 400
# Created a chunk of size 797, which is longer than the specified 400
# Created a chunk of size 3939, which is longer than the specified 400
# Created a chunk of size 924, which is longer than the specified 400
# Created a chunk of size 696, which is longer than the specified 400
# Created a chunk of size 854, which is longer than the specified 400
# Created a chunk of size 929, which is longer than the specified 400
# Created a chunk of size 549, which is longer than the specified 400
# Created a chunk of size 1020, which is longer than the specified 400
# Created a chunk of size 1109, which is longer than the specified 400
# Created a chunk of size 441, which is longer than the specified 400
# Created a chunk of size 1274, which is longer than the specified 400
# Created a chunk of size 1965, which is longer than the specified 400
# Created a chunk of size 541, which is longer than the specified 400
# Created a chunk of size 1530, which is longer than the specified 400
# Created a chunk of size 443, which is longer than the specified 400
# Created a chunk of size 439, which is longer than the specified 400
# Created a chunk of size 613, which is longer than the specified 400
# Created a chunk of size 1303, which is longer than the specified 400
# Created a chunk of size 520, which is longer than the specified 400
# Created a chunk of size 1000, which is longer than the specified 400
# Created a chunk of size 768, which is longer than the specified 400
# Created a chunk of size 562, which is longer than the specified 400
# Created a chunk of size 652, which is longer than the specified 400
# Created a chunk of size 1049, which is longer than the specified 400
# Created a chunk of size 1273, which is longer than the specified 400
# Created a chunk of size 951, which is longer than the specified 400
# Created a chunk of size 452, which is longer than the specified 400
# Created a chunk of size 683, which is longer than the specified 400
# Created a chunk of size 585, which is longer than the specified 400
# Created a chunk of size 1656, which is longer than the specified 400
# Created a chunk of size 764, which is longer than the specified 400
# Created a chunk of size 1033, which is longer than the specified 400

# %%
documents[0]
# Out:
# Document(metadata={'source': 'tagged_description.txt'}, page_content='9780002005883: A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.')

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

# Local (free) embedding model from Hugging Face
embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Store documents in Chroma vector database
db_books = Chroma.from_documents(
    documents,
    embedding=embedding_model
)

# %%
#simple test
query = "A book to teach children about nature"
docs = db_books.similarity_search(query, k=2)
docs
# Out:
# [Document(id='47c5961b-70ad-4f8e-a59e-094fa8ada709', metadata={'source': 'tagged_description.txt'}, page_content='9780786808069: Children will discover the exciting world of their own backyard in this introduction to familiar animals from cats and dogs to bugs and frogs. The combination of photographs, illustrations, and fun facts make this an accessible and delightful learning experience.'),
#  Document(id='d38d904c-afd6-4a03-b98b-9d594e563fbb', metadata={'source': 'tagged_description.txt'}, page_content='9780786808069: Children will discover the exciting world of their own backyard in this introduction to familiar animals from cats and dogs to bugs and frogs. The combination of photographs, illustrations, and fun facts make this an accessible and delightful learning experience.')]

# %%
books[books['isbn13'] == int(docs[0].page_content.split()[0].strip().rstrip(':'))]
# Out:
#              isbn13      isbn10                                title  \
# 3747  9780786808069  0786808063  Baby Einstein: Neighborhood Animals
#
#                                 authors        categories  \
# 3747  Marilyn Singer;Julie Aigner-Clark  Juvenile Fiction
#
#                                               thumbnail  \
# 3747  http://books.google.com/books/content?id=X9a4P...
#
#                                             description  published_year  \
# 3747  Children will discover the exciting world of t...          2001.0
#
#       average_rating  num_pages  ratings_count  \
# 3747            3.89       16.0          180.0
#
#                            title_subtitle  \
# 3747  Baby Einstein: Neighborhood Animals
#
#                                      tagged_description
# 3747  9780786808069: Children will discover the exci...

# %% [markdown]
# Step-by-step breakdown
# docs[0]
#
# From a list called docs, take the first document.
# (Urdu: docs list ka pehla document le rahe hain.)
#
# .page_content
#
# Get that document’s full text.
# (Is document ka pura text.)
#
# .split()
#
# Split the text into words (by spaces/newlines).
#
# Example: "9780306406157: A classic book" → ["9780306406157:", "A", "classic", "book"]
# (Text ko lafzon ki list me todta hai.)
#
# [0]
#
# Take the first word from that list.
#
# From the example: "9780306406157:"
# (Pehla lafz uthaya.)
#
# .strip()
#
# Remove any spaces at the start/end (if any).
#
# Example stays "9780306406157:"
# (Aagay/peechay ki khali jaga hata deta hai.)
#
# .rstrip(':')
#
# Remove a trailing colon : at the end if present.
#
# "9780306406157:" → "9780306406157"
# (Akhir me agar colon ho to hata do.)
#
# int( ... )
#
# Convert that cleaned string to an integer number.
#
# "9780306406157" → 9780306406157 (as an int)
# (Ab lafz ko number me badal diya.)
#
# books['isbn13'] == <that number>
#
# Make a True/False mask: for each row, check if its isbn13 equals that number.
#
# Result is something like: [False, True, False, ...]
# (Har row ke liye check: kya isbn13 barabar hai?)
#
# books[ <mask> ]
#
# Use that mask to filter the DataFrame.
#
# You get only the matching rows (the book with that ISBN).
# (Sirf wahi rows bachi jahan condition True thi.)

# %%
def retrieve_sementic_recommendation(query, top_k=50):
    docs = db_books.similarity_search(query, top_k)
    book_list = []

    for i in range(len(docs)):
        isbn_str = docs[i].page_content.strip('"').split()[0]  # pehla word lo
        isbn_str = isbn_str.rstrip(':')  # colon hatao
        book_list.append(int(isbn_str))  # ab int me convert karo

    return books[books['isbn13'].isin(book_list)]

# %%
retrieve_sementic_recommendation("A book to teach children about nature")
# Out:
#              isbn13      isbn10                                         title  \
# 59    9780007151240  0007151241                                The Family Way
# 324   9780060959036  0060959037                               Prodigal Summer
# 404   9780064402453  0064402452                    Racso and the Rats of NIMH
# 406   9780064403870  0064403874           R-T, Margaret, and the Rats of NIMH
# 407   9780064404419  0064404412                            The Rainbow People
# 416   9780064406925  006440692X                            Winter on the Farm
# 429   9780064434980  0064434982                          The Deer in the Wood
# 991   9780192862099  019286209X                           The Origins of Life
# 1078  9780241003008  0241003008                   The Very Hungry Caterpillar
# 1639  9780374422080  0374422087                        Everything on a Waffle
# 1642  9780374522599  0374522596                         The Control of Nature
# 1943  9780393959055  0393959058  Walden ; And, Resistance to Civil Government
# 3214  9780689861130  0689861133                           Moo, Baa, la la La!
# 3747  9780786808069  0786808063           Baby Einstein: Neighborhood Animals
# 3748  9780786808373  0786808373                          Baby Einstein: Birds
# 3749  9780786808380  0786808381                         Baby Einstein: Babies
# 3750  9780786808397  078680839X                           Baby Einstein: Dogs
# 3760  9780786812912  0786812915                                   The Big Box
# 3765  9780786819119  0786819111        Baby Einstein: Water, Water Everywhere
# 3834  9780802431486  0802431488              The 10 Commandments of Parenting
# 3933  9780811205467  0811205460                                 Turtle Island
# 4185  9780878937202  087893720X            Essentials of Conservation Biology
# 4264  9780941807555  094180755X        The Little Big Book for God's Children
# 4898  9781593851170  1593851170                            The Nature of Play
# 5189  9788122200850  8122200850                              Cry, the Peacock
#
#                                    authors            categories  \
# 59                            Tony Parsons            Parenthood
# 324                     Barbara Kingsolver               Fiction
# 404                      Jane Leslie Conly      Juvenile Fiction
# 406                      Jane Leslie Conly      Juvenile Fiction
# 407                           Laurence Yep      Juvenile Fiction
# 416                   Laura Ingalls Wilder      Juvenile Fiction
# 429                   Laura Ingalls Wilder      Juvenile Fiction
# 991      John Maynard Smith;Eörs Szathmáry               Science
# 1078                            Eric Carle     Babytime resource
# 1639                         Polly Horvath      Juvenile Fiction
# 1642                           John McPhee                Nature
# 1943                   Henry David Thoreau  Literary Collections
# 3214                        Sandra Boynton         Animal sounds
# 3747     Marilyn Singer;Julie Aigner-Clark      Juvenile Fiction
# 3748                    Julie Aigner-Clark      Juvenile Fiction
# 3749                    Julie Aigner-Clark      Juvenile Fiction
# 3750                    Julie Aigner-Clark      Juvenile Fiction
# 3760          Toni Morrison;Slade Morrison      Juvenile Fiction
# 3765                    Disney Book Group,      Juvenile Fiction
# 3834                        H. Edwin Young              Religion
# 3933                           Gary Snyder                Poetry
# 4185                    Richard B. Primack               Science
# 4264                Lena Tabori;Alice Wong              Religion
# 4898  Anthony D. Pellegrini;Peter K. Smith            Psychology
# 5189                           Anita Desai               Fiction
#
#                                               thumbnail  \
# 59    http://books.google.com/books/content?id=dJEIx...
# 324   http://books.google.com/books/content?id=06IwG...
# 404   http://books.google.com/books/content?id=MgoNv...
# 406   http://books.google.com/books/content?id=WTHHH...
# 407   http://books.google.com/books/content?id=5AHwq...
# 416   http://books.google.com/books/content?id=IvlKH...
# 429   http://books.google.com/books/content?id=V7YDW...
# 991   http://books.google.com/books/content?id=nHDbB...
# 1078  http://books.google.com/books/content?id=DpGEQ...
# 1639  http://books.google.com/books/content?id=NimVJ...
# 1642  http://books.google.com/books/content?id=p1qKQ...
# 1943  http://books.google.com/books/content?id=uVxnQ...
# 3214  http://books.google.com/books/content?id=Gz40A...
# 3747  http://books.google.com/books/content?id=X9a4P...
# 3748  http://books.google.com/books/content?id=0jxHP...
# 3749  http://books.google.com/books/content?id=jv4NA...
# 3750  http://books.google.com/books/content?id=qut8t...
# 3760  http://books.google.com/books/content?id=LyYKA...
# 3765  http://books.google.com/books/content?id=tuAdA...
# 3834  http://books.google.com/books/content?id=Q1Hxj...
# 3933  http://books.google.com/books/content?id=xilff...
# 4185  http://books.google.com/books/content?id=spaGQ...
# 4264  http://books.google.com/books/content?id=s2PfT...
# 4898  http://books.google.com/books/content?id=Nukz6...
# 5189  http://books.google.com/books/content?id=_QKwV...
#
#                                             description  published_year  \
# 59    It should be the most natural thing in the wor...          2005.0
# 324   Barbara Kingsolver's fifth novel is a hymn to ...          2001.0
# 404   ‘Racso, a brash and boastful little rodent, is...          1988.0
# 406   When Margaret and her younger brother, Artie, ...          1991.0
# 407   "Culled from 69 stories collected in a [1930s]...          1992.0
# 416   The Little House books tell the story of a lit...          1997.0
# 429   Even the youngest child can enjoy a special ad...          1999.0
# 991   'I can recommend this book as a thoroughly int...          2000.0
# 1078  Eric Carle's children's classic is the story o...          1994.0
# 1639  This Newbery Honor Book tells the story of 11 ...          2004.0
# 1642  The Control of Nature is John McPhee's bestsel...          1990.0
# 1943  The classic chronicle of a communion with natu...          1992.0
# 3214  Children will love joining in and imitating th...          2004.0
# 3747  Children will discover the exciting world of t...          2001.0
# 3748  Introducing your baby to birds, cats, dogs, an...          2002.0
# 3749  Introduce your babies to birds, cats, dogs, an...          2002.0
# 3750  Introduce your baby to birds, cats, dogs, and ...          2002.0
# 3760  In her first illustrated book for children, th...          2002.0
# 3765  Charming illustrations and playful rhythmic ve...          2003.0
# 3834  Drawn from years of counseling and the author'...          2005.0
# 3933  These Pulitzer Prize-winning poems and essays ...          1974.0
# 4185  Essentials of Conservation Biology (Fourth Edi...          2006.0
# 4264  THE LITTLE BIG BOOK FOR GOD'S CHILDREN is a wo...          2001.0
# 4898  "Comprehensive and up to date, this tightly ed...          2005.0
# 5189  This book is the story of a young girl obsesse...          1980.0
#
#       average_rating  num_pages  ratings_count  \
# 59              3.51      400.0         2095.0
# 324             4.00      444.0        85440.0
# 404             3.76      288.0         3231.0
# 406             3.52      272.0          631.0
# 407             3.75      208.0          202.0
# 416             4.13       32.0          400.0
# 429             4.17       32.0          302.0
# 991             4.11      192.0           41.0
# 1078            4.29       26.0       340101.0
# 1639            3.71      150.0         9631.0
# 1642            4.24      288.0         3365.0
# 1943            3.95      482.0          232.0
# 3214            4.20       14.0        28261.0
# 3747            3.89       16.0          180.0
# 3748            3.78       20.0            9.0
# 3749            4.03       20.0           29.0
# 3750            3.81       20.0           26.0
# 3760            3.95       48.0          375.0
# 3765            3.70       10.0           77.0
# 3834            4.00      224.0           25.0
# 3933            4.09      112.0         3717.0
# 4185            3.89      585.0           36.0
# 4264            4.88      352.0            8.0
# 4898            4.25      308.0            4.0
# 5189            3.22      218.0          134.0
#
#                                          title_subtitle  \
# 59                                       The Family Way
# 324                            Prodigal Summer: A Novel
# 404                          Racso and the Rats of NIMH
# 406                 R-T, Margaret, and the Rats of NIMH
# 407                                  The Rainbow People
# 416                                  Winter on the Farm
# 429                                The Deer in the Wood
# 991   The Origins of Life: From the Birth of Life to...
# 1078                        The Very Hungry Caterpillar
# 1639                             Everything on a Waffle
# 1642                              The Control of Nature
# 1943  Walden ; And, Resistance to Civil Government: ...
# 3214                                Moo, Baa, la la La!
# 3747                Baby Einstein: Neighborhood Animals
# 3748                               Baby Einstein: Birds
# 3749                              Baby Einstein: Babies
# 3750                                Baby Einstein: Dogs
# 3760                                        The Big Box
# 3765             Baby Einstein: Water, Water Everywhere
# 3834  The 10 Commandments of Parenting: The Do's and...
# 3933                                      Turtle Island
# 4185                 Essentials of Conservation Biology
# 4264             The Little Big Book for God's Children
# 4898          The Nature of Play: Great Apes and Humans
# 5189                                   Cry, the Peacock
#
#                                      tagged_description
# 59    9780007151240: It should be the most natural t...
# 324   9780060959036: Barbara Kingsolver's fifth nove...
# 404   9780064402453: ‘Racso, a brash and boastful li...
# 406   9780064403870: When Margaret and her younger b...
# 407   9780064404419: "Culled from 69 stories collect...
# 416   9780064406925: The Little House books tell the...
# 429   9780064434980: Even the youngest child can enj...
# 991   9780192862099: 'I can recommend this book as a...
# 1078  9780241003008: Eric Carle's children's classic...
# 1639  9780374422080: This Newbery Honor Book tells t...
# 1642  9780374522599: The Control of Nature is John M...
# 1943  9780393959055: The classic chronicle of a comm...
# 3214  9780689861130: Children will love joining in a...
# 3747  9780786808069: Children will discover the exci...
# 3748  9780786808373: Introducing your baby to birds,...
# 3749  9780786808380: Introduce your babies to birds,...
# 3750  9780786808397: Introduce your baby to birds, c...
# 3760  9780786812912: In her first illustrated book f...
# 3765  9780786819119: Charming illustrations and play...
# 3834  9780802431486: Drawn from years of counseling ...
# 3933  9780811205467: These Pulitzer Prize-winning po...
# 4185  9780878937202: Essentials of Conservation Biol...
# 4264  9780941807555: THE LITTLE BIG BOOK FOR GOD'S C...
# 4898  9781593851170: "Comprehensive and up to date, ...
# 5189  9788122200850: This book is the story of a you...
